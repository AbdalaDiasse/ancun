# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
from tensorflow.contrib.layers import fully_connected
from sklearn.preprocessing import MinMaxScaler
import scipy.stats as ss
from scipy.integrate import quad

# %%
# %matplotlib notebook

# %%
sensor_file= './data/kiln_sensor/sensor_data.csv'
dataset =  pd.read_csv(sensor_file)

# %%
time=  dataset.iloc[:,0].values.reshape(-1,1)
sensor1=  dataset.iloc[:,1].values.reshape(-1,1)
sensor2=  dataset.iloc[:,2].values.reshape(-1,1)
sensor3=  dataset.iloc[:,3].values.reshape(-1,1)
sensor4=  dataset.iloc[:,4].values.reshape(-1,1)
sensor5=  dataset.iloc[:,5].values.reshape(-1,1)
sensor6=  dataset.iloc[:,6].values.reshape(-1,1)
sensor7=  dataset.iloc[:,7].values.reshape(-1,1)
sensor8=  dataset.iloc[:,8].values.reshape(-1,1)
sensor9=  dataset.iloc[:,9].values.reshape(-1,1)
sensor10=  dataset.iloc[:,10].values.reshape(-1,1)
sensor11=  dataset.iloc[:,11].values.reshape(-1,1)
sensor12=  dataset.iloc[:,12].values.reshape(-1,1)
sensor13=  dataset.iloc[:,13].values.reshape(-1,1)
sensor14=  dataset.iloc[:,14].values.reshape(-1,1)
sensor15=  dataset.iloc[:,15].values.reshape(-1,1)
sensor16=  dataset.iloc[:,16].values.reshape(-1,1)
sensor17=  dataset.iloc[:,17].values.reshape(-1,1)
sensor18=  dataset.iloc[:,18].values.reshape(-1,1)
sensor19=  dataset.iloc[:,19].values.reshape(-1,1)
sensor20=  dataset.iloc[:,20].values.reshape(-1,1)
sensor21=  dataset.iloc[:,21].values.reshape(-1,1)
sensor22=  dataset.iloc[:,22].values.reshape(-1,1)
sensor23=  dataset.iloc[:,23].values.reshape(-1,1)
sensor24=  dataset.iloc[:,24].values.reshape(-1,1)
sensor25=  dataset.iloc[:,25].values.reshape(-1,1)
sensor26=  dataset.iloc[:,26].values.reshape(-1,1)
sensor27=  dataset.iloc[:,27].values.reshape(-1,1)
sensor28=  dataset.iloc[:,28].values.reshape(-1,1)

# %%
scaler_1 = MinMaxScaler()
scaler_2 = MinMaxScaler()
scaler_3 = MinMaxScaler()
scaler_4 = MinMaxScaler()
scaler_5 = MinMaxScaler()
scaler_6 = MinMaxScaler()
scaler_7 = MinMaxScaler()
scaler_8 = MinMaxScaler()
scaler_9 = MinMaxScaler()
scaler_10 = MinMaxScaler()
scaler_11= MinMaxScaler()
scaler_12 = MinMaxScaler()
scaler_13 = MinMaxScaler()
scaler_14 = MinMaxScaler()
scaler_15 = MinMaxScaler()
scaler_16 = MinMaxScaler()
scaler_17 = MinMaxScaler()
scaler_18 = MinMaxScaler()
scaler_19 = MinMaxScaler()
scaler_20 = MinMaxScaler()
scaler_21 = MinMaxScaler()
scaler_22 = MinMaxScaler()
scaler_23 = MinMaxScaler()
scaler_24 = MinMaxScaler()
scaler_25 = MinMaxScaler()
scaler_26 = MinMaxScaler()
scaler_27 = MinMaxScaler()
scaler_28 = MinMaxScaler()

# %%
X_train1 = scaler_1.fit_transform(sensor1).reshape(-1)
X_train2 = scaler_2.fit_transform(sensor2).reshape(-1)
X_train3 = scaler_3.fit_transform(sensor3).reshape(-1)
X_train4 = scaler_4.fit_transform(sensor4).reshape(-1)
X_train5 = scaler_5.fit_transform(sensor5).reshape(-1)
X_train6 = scaler_6.fit_transform(sensor6).reshape(-1)
X_train7 = scaler_7.fit_transform(sensor7).reshape(-1)
X_train8 = scaler_8.fit_transform(sensor8).reshape(-1)
X_train9 = scaler_9.fit_transform(sensor9).reshape(-1)
X_train10 = scaler_10.fit_transform(sensor10).reshape(-1)
X_train11 = scaler_11.fit_transform(sensor11).reshape(-1)
X_train12 = scaler_12.fit_transform(sensor12).reshape(-1)
X_train13 = scaler_13.fit_transform(sensor13).reshape(-1)
X_train14 = scaler_14.fit_transform(sensor14).reshape(-1)
X_train15 = scaler_15.fit_transform(sensor15).reshape(-1)
X_train16 = scaler_16.fit_transform(sensor16).reshape(-1)
X_train17 = scaler_17.fit_transform(sensor17).reshape(-1)
X_train18 = scaler_18.fit_transform(sensor18).reshape(-1)
X_train19 = scaler_19.fit_transform(sensor19).reshape(-1)
X_train20 = scaler_20.fit_transform(sensor20).reshape(-1)
X_train21 = scaler_21.fit_transform(sensor21).reshape(-1)
X_train22 = scaler_22.fit_transform(sensor22).reshape(-1)
X_train23 = scaler_23.fit_transform(sensor23).reshape(-1)
X_train24 = scaler_24.fit_transform(sensor24).reshape(-1)
X_train25 = scaler_25.fit_transform(sensor25).reshape(-1)
X_train26 = scaler_26.fit_transform(sensor26).reshape(-1)
X_train27 = scaler_27.fit_transform(sensor27).reshape(-1)
X_train28 = scaler_28.fit_transform(sensor28).reshape(-1)

# %%
X_test1 = X_train1
X_test2 = X_train2
X_test3 = X_train3
X_test4 = X_train4
X_test5 = X_train5
X_test6 = X_train6
X_test7 = X_train7
X_test8 = X_train8
X_test9 = X_train9
X_test10 = X_train10
X_test11 = X_train11
X_test12 = X_train12
X_test13 = X_train13
X_test14 = X_train14
X_test15 = X_train15
X_test16 = X_train16
X_test17 = X_train17
X_test18 = X_train18
X_test19 = X_train19
X_test20 = X_train20
X_test21 = X_train21
X_test22 = X_train22
X_test23 = X_train23
X_test24 = X_train24
X_test25 = X_train25
X_test26 = X_train26
X_test27 = X_train27
X_test28 = X_train28

# %%
plt.figure()
plt.plot(X_test12)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
seq_len = 128

batch_size = 4

def generate_sequence(data,seq_len):
    
    num_sequence =  len(data) // seq_len
    
    all_sequence = []
    for i in range(num_sequence):
        all_sequence.append(data[i*seq_len:(i+1)*seq_len])
    return all_sequence 

def generate_batch(data , batch_size):
    
    num_batch =  len(data) // batch_size
    train_data = []
    for i in range(num_batch):
        train_data.append(data[i*batch_size:(i+1)*batch_size])
    return train_data

# %%
def normal_data_extractor(data, mylist,seq_len,batch_size):
    all_data =[]
    for i in range(len(mylist)):
        values =mylist[i]
        subdata =  data[values[0]:values[1]]
        subdata_seq = generate_sequence(subdata,seq_len)
        subdata_seq_batch = generate_batch(subdata_seq , batch_size)
        all_data.extend(subdata_seq_batch)
    return all_data

# %%
list_12 = [[0,10000],[15400,28000],[80000,115000],[120000,200000],[220000,850000],
           [1000000,2000000],[3000000,3700000],[4200000,6000000],[8400000,860000],
          [8700000,9100000],[9400000,9750000]]

list_12 = [[0,10000],[15400,28000],[80000,115000],[120000,200000],[220000,850000],
           [1000000,2000000],[2100000,2700000],[3000000,3700000],[4200000,6000000],[8400000,860000],
          [8700000,9100000],[9400000,9750000]]

list_12 = [[0,10000],[15400,28000],[80000,115000],[120000,200000],[220000,850000],
           [1000000,2000000],[2100000,2700000],[2720000,2900000],[3000000,3700000],[4200000,6000000],[8400000,860000],
          [8700000,9100000],[9400000,9750000],[9800000,10100000],[10200000,10680000],[11020000,11370000],[12600000,13100000]]

X_train_batch12 = normal_data_extractor(X_train12, list_12,seq_len,batch_size)

list_18 = [[0,29000],[80000,180000],[300000,1900000],[1960000,2100000],[2230000,2460000],
           [3420000,3720000],[3825000,4050000],[4100000,5700000],[5750000,6600000],
           [8200000,9200000],[9400000,11300000],[11800000,12600000],[12700000,13100000]]
X_train_batch18 = normal_data_extractor(X_train18, list_18,seq_len,batch_size)

list_5 = [[620000,2000000]]
X_train_batch5 = normal_data_extractor(X_train5, list_5,seq_len,batch_size)

# %%
len(X_train_batch18)
# Out:
# 17913

# %%
X_test_seq12 = generate_sequence(X_test12,seq_len)
X_test_batch12 = generate_batch(X_test_seq12, batch_size)

X_test_seq18 = generate_sequence(X_test18,seq_len)
X_test_batch18 = generate_batch(X_test_seq18, batch_size)

X_test_seq5 = generate_sequence(X_test5,seq_len)
X_test_batch5 = generate_batch(X_test_seq5, batch_size)

# %%
from keras.models import Sequential, Model
from keras.layers import LSTM, RepeatVector, Input
import keras
from keras import optimizers
# Out:
# Using TensorFlow backend.

# %%
def rnn_DAE(X_train,time_step , input_size , hidden_dim):

    inputs = Input(shape=(time_step,input_size))
    encoded = LSTM(hidden_dim)(inputs)

    decoded = RepeatVector(time_step)(encoded)
    decoded = LSTM(input_size, return_sequences=True)(decoded)

    sequence_autoencoder = Model(inputs, decoded)
    
    adam = optimizers.Adam(lr=0.001)
    
    sequence_autoencoder.compile(optimizer=adam, loss='mse')

    history = sequence_autoencoder.fit(X_train, X_train, nb_epoch=50, batch_size=100)
    
    return sequence_autoencoder

# %%
lstm_DAE = rnn_DAE(X_train_batch12, batch_size , seq_len , 32)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:15: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   from ipykernel import kernelapp as app
# Epoch 1/50
# 14499/14499 [==============================] - 4s 249us/step - loss: 0.0829
# Epoch 2/50
# 14499/14499 [==============================] - 3s 181us/step - loss: 0.0048
# Epoch 3/50
# 14499/14499 [==============================] - 3s 179us/step - loss: 0.0044
# Epoch 4/50
# 14499/14499 [==============================] - 3s 179us/step - loss: 0.0031
# Epoch 5/50
# 14499/14499 [==============================] - 3s 176us/step - loss: 0.0021
# Epoch 6/50
# 14499/14499 [==============================] - 3s 184us/step - loss: 0.0018
# Epoch 7/50
# 14499/14499 [==============================] - 3s 177us/step - loss: 0.0017
# Epoch 8/50
# 14499/14499 [==============================] - 3s 186us/step - loss: 0.0016
# Epoch 9/50
# ...

# %%
test_output = lstm_DAE.predict(X_test_batch12)

# %%
train_output = lstm_DAE.predict(X_train_batch12)

# %%
def deepautoencoder(layer , num_inputs,X,activation):
    hidden_layer = []
    hidden_layer.append(X)
    for i in range(0,len(layer)):
        hidden = fully_connected(hidden_layer[i], layer[i], activation_fn=activation)
        hidden_layer.append(hidden)
    output_layer = fully_connected(hidden_layer[i+1], num_inputs, activation_fn=None)
    middle_layer = hidden_layer[len(hidden_layer)//2]
    return output_layer , middle_layer

# %%
tf.reset_default_graph()

# %%
tf.reset_default_graph() 
def train_DAE(num_inputs,layer , num_epochs , learning_rate,X_train_batch ,X_test_batch ):
    
    actf = tf.nn.relu
    act_func = tf.nn.relu
    X = tf.placeholder(tf.float32, shape=[None, num_inputs])
    initializer = tf.variance_scaling_initializer()
    output_layer , middle_layer = deepautoencoder(layer ,num_inputs,X, act_func)
    loss = tf.reduce_mean(tf.square(output_layer - X))
    
    #tf.train.RMSPropOptimizer
    optimizer = tf.train.AdamOptimizer(learning_rate)
    train = optimizer.minimize(loss)
    init = tf.global_variables_initializer()
    saver = tf.train.Saver() 
    
    
    # Training
    with tf.Session() as sess:
        sess.run(init)

        # Epoch == Entire Training Set
        for epoch in range(num_epochs):
            
            all_loss = []
            num_batches = len(X_train_batch)
            X_batch = X_train_batch[0]
            for iteration in range(1,num_batches):
                sess.run(train, feed_dict={X: X_batch})
                X_batch = X_train_batch[iteration]
                all_loss.append(loss.eval(feed_dict={X: X_batch}) )
                

            training_loss = np.array(all_loss).mean()

            print("Epoch {} Complete. Training Loss: {}".format(epoch,training_loss))


        train_lost = []
        train_output = []
        X_batch_train =  X_train_batch[0]
        for i in range(0,len(X_train_batch)):
            train_lost.append(loss.eval(feed_dict = {X:X_batch_train}))
            train_output.append(output_layer.eval(feed_dict = {X:X_batch_train} ))
            X_batch_train =  X_train_batch[i]


        test_lost = []
        test_output = []
        X_batch_test =  X_test_batch[0]
        for i in range(0,len(X_test_batch)):
            test_lost.append(loss.eval(feed_dict = {X:X_batch_test}))
            test_output.append(output_layer.eval(feed_dict = {X:X_batch_test} ))
            X_batch_test =  X_test_batch[i]
            
        return train_output , test_output

# %%
def pdf_expo(mse,lambda_):
    return lambda_*np.exp(-lambda_*np.array(mse))

# %%
def compute_exponential_distribution(mse):
    n = len(mse)
    lambda_ = (n)/sum(mse)
    return lambda_

# %%
def prob_expo(error, lambda_):
    return np.exp(-lambda_*np.array(error))

# %%
def compute_error(X_input, X_recons):
    mse_all = []
    for i in range(len(X_input)):
        mse = ((X_input[i] - X_recons[i]) ** 2).mean(axis=1)
        mse_all.extend(mse)
    return mse_all

# %%
train_data = X_train_batch12
test_data = X_test_batch12

# %%
#100,96,48,32,16,32,48,96,100
train_output , test_output = train_DAE(seq_len,[100,70,50,40,30,40,50,70,100],70,0.01,train_data,test_data)
# Out:
# Epoch 0 Complete. Training Loss: 0.006308174692094326
# Epoch 1 Complete. Training Loss: 0.002453622641041875
# Epoch 2 Complete. Training Loss: 0.0012317511718720198
# Epoch 3 Complete. Training Loss: 0.0007079674396663904
# Epoch 4 Complete. Training Loss: 0.001227271044626832
# Epoch 5 Complete. Training Loss: 0.000578018429223448
# Epoch 6 Complete. Training Loss: 0.001369742094539106
# Epoch 7 Complete. Training Loss: 0.0006513785338029265
# Epoch 8 Complete. Training Loss: 0.0006325166905298829
# Epoch 9 Complete. Training Loss: 0.0007092290907166898
# Epoch 10 Complete. Training Loss: 0.0023222025483846664
# Epoch 11 Complete. Training Loss: 0.0009757874067872763
# Epoch 12 Complete. Training Loss: 0.0008411709568463266
# Epoch 13 Complete. Training Loss: 0.0006636664038524032
# Epoch 14 Complete. Training Loss: 0.000666036328766495
# Epoch 15 Complete. Training Loss: 0.0007695930544286966
# Epoch 16 Complete. Training Loss: 0.0006372614298015833
# ...

# %%
mse_train = compute_error(train_data,train_output)
lambda_expon = compute_exponential_distribution(mse_train)
prob_train = prob_expo(mse_train, lambda_expon)

# %%
mse_test = compute_error(test_data,test_output)
prob_test = prob_expo(mse_test, lambda_expon)

# %%
# a is your data array
plt.figure(figsize=(10, 8))
plt.subplot(411)
plt.hist(mse_train,100)
plt.subplot(412)
plt.plot(mse_train)
plt.subplot(413)
plt.hist(prob_train)
plt.subplot(414)
plt.plot(X_train18)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="999.1666666666667">

# %%
# a is your data array
plt.figure()
sort_data = mse_train
sort_data.sort()
plt.hist(mse_train,100)
h = plt.plot(mse_train, pdf_expo(mse_train,lambda_expon), lw=2)
#h = plt.plot(mse_train,ss.norm.pdf(mse_train, 0.00019, 0.000107), lw=2)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
from sklearn.neighbors import KernelDensity

# %%
# kernel density estimate using sklean 
fig, ax = plt.subplots()

X =np.array(mse_train).reshape((-1,1))
bandwidth = np.std(mse_train)
for kernel in ['gaussian', 'exponential']:
       
    kde = KernelDensity(kernel=kernel,bandwidth = 0.0001).fit(X)
    X_plot = np.linspace(0, 0.03, 1000)[:, np.newaxis]
    log_dens = kde.score_samples(X_plot)
    ax.plot(X_plot, np.exp(log_dens), '-',
            label="kernel = '{0}'".format(kernel))
    
#ax.plot(X[:, 0], -0.005 - 0.01*np.random.random(X.shape[0]), '+k')
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
np.array(mse_train).shape
# Out:
# (57996,)

# %%
#Kernel density estimate using scipy 
fig, ax = plt.subplots()
kde_sp = ss.gaussian_kde(np.array(mse_train))
X_plot = np.linspace(0, 0.01, 1000)[:, np.newaxis]
X_plot= X_plot.reshape(-1)
log_dens = kde_sp.pdf(X_plot)
ax.plot(X_plot, log_dens, '-',)
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
def compute_prob_scipy(all_mse, integrale_range , kde):
    probs = []
    for i in range(len(all_mse)):
        if i%1000 == 0:
            print('Iteration = ',i)
        mse =  all_mse[i]
        probs.append(kde.integrate_box_1d(mse - integrale_range, mse +integrale_range))
    
    return probs

# %%
def compute_prob_sklean(all_mse, integrale_range , kde):
    probs = []
    for i in range(len(all_mse)):
        mse =  all_mse[i]
        probs.append(quad(lambda x: np.exp(kde.score_samples(x)), mse - integrale_range, mse +integrale_range)[0])
        #print("mse:",mse,"prob :",probs[i])
    return probs

# %%
len(mse_test)
# Out:
# 103648

# %%
prob_train2  = compute_prob_scipy(mse_train , 0.001, kde_sp)

# %%
prob_test2   = compute_prob_scipy(mse_test , 0.0005, kde_sp)
# Out:
# Iteration =  0
# Iteration =  1000
# Iteration =  2000
# Iteration =  3000
# Iteration =  4000
# Iteration =  5000
# Iteration =  6000
# Iteration =  7000
# Iteration =  8000
# Iteration =  9000
# Iteration =  10000
# Iteration =  11000
# Iteration =  12000
# Iteration =  13000
# Iteration =  14000
# Iteration =  15000
# Iteration =  16000
# Iteration =  17000
# Iteration =  18000
# Iteration =  19000
# Iteration =  20000
# Iteration =  21000
# Iteration =  22000
# Iteration =  23000
# Iteration =  24000
# Iteration =  25000
# Iteration =  26000
# Iteration =  27000
# Iteration =  28000
# Iteration =  29000
# Iteration =  30000
# Iteration =  31000
# Iteration =  32000
# Iteration =  33000
# Iteration =  34000
# Iteration =  35000
# Iteration =  36000
# Iteration =  37000
# Iteration =  38000
# Iteration =  39000
# Iteration =  40000
# Iteration =  41000
# Iteration =  42000
# Iteration =  43000
# Iteration =  44000
# Iteration =  45000
# Iteration =  46000
# Iteration =  47000
# ...

# %%
max(prob_test2)
# Out:
# 0.79622095692514394

# %%
# a is your data array
plt.figure(figsize=(10, 8))
plt.subplot(411)
plt.hist(mse_test,100)
plt.subplot(412)
plt.plot(mse_test)
plt.subplot(413)
plt.plot(prob_test2)
plt.subplot(414)
plt.plot(prob_test2)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="999.1666666666667">

# %%
min_error = min(prob_test2)
min_error
# Out:
# 0.0

# %%
def find_anomalies_prob(prob,threshold,windows):
    list_anomalies = []
    n_windows = len(prob)//windows
    print(n_windows)
    for i in range(n_windows):
        data = prob[i*windows:(i+1)*windows]
        threshold =  np.std(data)/2
        for j in range(windows):
            if prob[i*windows + j]<=threshold or  prob[i*windows + j]== 0:
                list_anomalies.append(i*windows + j)
    return list_anomalies

# %%
def find_anomalies_prob(prob,threshold):
    list_anomalies = []
    for i in range(len(prob)):
        if prob[i]<=threshold:
            list_anomalies.append(i)
    return list_anomalies

# %%
len(prob_test2)
# Out:
# 103648

# %%
'''
fOR C5
threshold = 1.24e-02
threshold = 0.02 #C5AT01
threshold = 0.1 #C5BT01
threshold = 0.1#C5AT02
threshold = 0.1#C5BT02
threshold = 0.1#C5AT03
'''

threshold = 0.002#C4AT01
#threshold = 0.1  #C4BT01
#threshold = 0.1  #C4AT02
#threshold = 0.1  #C4BT02


list_anomlies = find_anomalies_prob(prob_test2,threshold)

# %%
def find_contiguous_colors(colors):
    # finds the continuous segments of colors and returns those segments
    segs = []
    curr_seg = []
    prev_color = ''
    for c in colors:
        if c == prev_color or prev_color == '':
            curr_seg.append(c)
        else:
            segs.append(curr_seg)
            curr_seg = []
            curr_seg.append(c)
        prev_color = c
    segs.append(curr_seg) # the final one
    return segs
 
def plot_multicolored_lines(x,y,colors):
    segments = find_contiguous_colors(colors)
    plt.figure(figsize=(10, 3))
    start= 0
    for seg in segments:
        end = start + len(seg)
        if start == 0 :
            l, = plt.gca().plot(x[start:end],y[start:end],lw=2,c=seg[0])
        else:
            l, = plt.gca().plot(x[start-1:end],y[start-1:end],lw=2,c=seg[0])
        start = end
    return segments

# %%
def plot_anomalies(anomalies, data,seq_len,scaler):
    data = scaler.inverse_transform(data.reshape(-1,1))
    colors = []
    for i in range(len(data)):
        colors.append('blue')
        
    for i in range(len(anomalies)):
        one_anomalies = anomalies[i]*seq_len
        for j in range(seq_len):
            colors[one_anomalies+j] = 'red'
    x = range(len(data))
    y = data 

    segments = plot_multicolored_lines(x,y,colors)
    plt.show()
    return

# %%
plot_anomalies(list_anomlies, X_test12,seq_len,scaler_12)
# Out:
# <img src="data:image/png;base64,..." width="999.1666666666667">

# %%
def anamalie_detection(sensors , model):
# Out:
#   File "<ipython-input-1623-99e8dd457cd1>", line 1
#     def anamalie_detection(sensors , model):
#                                             ^
# SyntaxError: unexpected EOF while parsing

# %%
list_18 = [[0,29000],[80000,180000],[300000,1900000],[1960000,2100000],[2230000,2460000],
           [3420000,3720000],[3825000,4050000],[4100000,5700000],[5750000,6600000],
           [8200000,9200000],[9400000,11300000],[11800000,12600000],[12700000,13100000]]
